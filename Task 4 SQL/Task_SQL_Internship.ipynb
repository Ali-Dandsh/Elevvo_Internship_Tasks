# %%
#import Libraries
import sqlite3
import pandas as pd

# %%
#Get The Path
path = r"D:\Elevvo_Internship\Task 4 SQL\Chinook_Sqlite.sqlite"

# %%
#Connection
conn=sqlite3.connect(path)

# %%
# Show The Whole DataBase Tables
tables = pd.read_sql("""SELECT * FROM sqlite_master WHERE type = 'table'; """, conn)
tables
# Out:
#      type           name       tbl_name  rootpage  \
# 0   table          Album          Album        19
# 1   table         Artist         Artist       281
# 2   table       Customer       Customer       386
# 3   table       Employee       Employee       392
# 4   table          Genre          Genre       395
# 5   table        Invoice        Invoice       396
# 6   table    InvoiceLine    InvoiceLine       399
# 7   table      MediaType      MediaType       402
# 8   table       Playlist       Playlist       404
# 9   table  PlaylistTrack  PlaylistTrack       405
# 10  table          Track          Track       409
#
#                                                   sql
# 0   CREATE TABLE [Album]\n(\n    [AlbumId] INTEGER...
# 1   CREATE TABLE [Artist]\n(\n    [ArtistId] INTEG...
# 2   CREATE TABLE [Customer]\n(\n    [CustomerId] I...
# 3   CREATE TABLE [Employee]\n(\n    [EmployeeId] I...
# 4   CREATE TABLE [Genre]\n(\n    [GenreId] INTEGER...
# ...

# %%
Album=pd.read_sql(""" SELECT * FROM  Album """, conn)
Album
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
Invoice=pd.read_sql(""" SELECT * FROM  Invoice """, conn)
Invoice
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
InvoiceLine = pd.read_sql(""" SELECT * FROM  InvoiceLine """, conn)
InvoiceLine
# Out:
#       InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0                 1          1        2       0.99         1
# 1                 2          1        4       0.99         1
# 2                 3          2        6       0.99         1
# 3                 4          2        8       0.99         1
# 4                 5          2       10       0.99         1
# ...             ...        ...      ...        ...       ...
# 2235           2236        411     3136       0.99         1
# 2236           2237        411     3145       0.99         1
# 2237           2238        411     3154       0.99         1
# 2238           2239        411     3163       0.99         1
# 2239           2240        412     3177       1.99         1
#
# [2240 rows x 5 columns]

# %%
Customer = pd.read_sql(""" SELECT * FROM  Customer """, conn)
Customer
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
Track = pd.read_sql(""" SELECT * FROM  Track """, conn)
Track
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %%
Total_Sales = pd.read_sql( """SELECT SUM(Total) AS TOTAL_SALES FROM INVOICE  """,conn)
Total_Sales
# Out:
#    TOTAL_SALES
# 0       2328.6

# %%
Num_Sold_Products = pd.read_sql("""SELECT COUNT(DISTINCT(TRACKID)) AS NUM_OF_TRACKS_SOLD   FROM INVOICElINE""",conn)
Num_Sold_Products
# Out:
#    NUM_OF_TRACKS_SOLD
# 0                1984

# %%
Num_Sold_ALBUMS = pd.read_sql("""SELECT COUNT(DISTINCT(ALBUMID)) AS NUM_OF_ALBUMS_SOLD   FROM TRACK""",conn)
Num_Sold_ALBUMS
# Out:
#    NUM_OF_ALBUMS_SOLD
# 0                 347

# %%
TOP_sales_by_track= pd.read_sql("""select T.Name,SUM(IL.UNITPRICE*IL.QUANTITY) as TotalSales FROM TRACK AS T INNER JOIN INVOICELINE AS IL ON T.TRACKID == IL.TRACKID GROUP BY T.NAME ORDER BY 
TotalSales DESC
LIMIT 10""",conn)
TOP_sales_by_track
# Out:
#                            Name  TotalSales
# 0                   The Trooper        4.95
# 1                     Walkabout        3.98
# 2                The Woman King        3.98
# 3                       The Fix        3.98
# 4                         Pilot        3.98
# 5             Phyllis's Wedding        3.98
# 6  How to Stop an Exploding Man        3.98
# 7                      Hot Girl        3.98
# 8                Gay Witch Hunt        3.98
# 9                Branch Closing        3.98

# %%
regions=pd.read_sql("""select distinct(country) from customer """,conn)
regions
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %%
revenue_per_region=pd.read_sql("""select country as Regions,sum(I.TOTAL) as T_SALES from customer as c inner join invoice as i on c.customerid==i.customerid group by regions  order by T_sales DESC """,conn)
revenue_per_region
# Out:
#            Regions  T_SALES
# 0              USA   523.06
# 1           Canada   303.96
# 2           France   195.10
# 3           Brazil   190.10
# 4          Germany   156.48
# 5   United Kingdom   112.86
# 6   Czech Republic    90.24
# 7         Portugal    77.24
# 8            India    75.26
# 9            Chile    46.62
# 10         Ireland    45.62
# 11         Hungary    45.62
# 12         Austria    42.62
# 13         Finland    41.62
# 14     Netherlands    40.62
# 15          Norway    39.62
# 16          Sweden    38.62
# 17           Spain    37.62
# 18          Poland    37.62
# 19           Italy    37.62
# 20         Denmark    37.62
# 21         Belgium    37.62
# 22       Australia    37.62
# 23       Argentina    37.62

# %%
date=pd.read_sql("""select date(invoicedate) as date_only from invoice """,conn) 
date
# Out:
#       date_only
# 0    2009-01-01
# 1    2009-01-02
# 2    2009-01-03
# 3    2009-01-06
# 4    2009-01-11
# ..          ...
# 407  2013-12-05
# 408  2013-12-06
# 409  2013-12-09
# 410  2013-12-14
# 411  2013-12-22
#
# [412 rows x 1 columns]

# %%
date_months = pd.read_sql("""
SELECT 
    strftime('%m', InvoiceDate) AS Month,
    COUNT(i.InvoiceId) AS Num_Invoices,
    COUNT(DISTINCT i.CustomerId) AS Num_Customers,
    SUM(il.Quantity) AS Total_Quantity,
    SUM(IL.UNITPRICE*IL.QUANTITY) AS Total_Sales
FROM Invoice AS i
INNER JOIN InvoiceLine AS il 
    ON i.InvoiceId = il.InvoiceId
GROUP BY strftime('%m', InvoiceDate)
ORDER BY Month;
""", conn)

date_months
# Out:
#    Month  Num_Invoices  Num_Customers  Total_Quantity  Total_Sales
# 0     01           188             34             188       201.12
# 1     02           180             33             180       187.20
# 2     03           190             35             190       195.10
# 3     04           186             33             186       198.14
# 4     05           190             35             190       193.10
# 5     06           190             35             190       201.10
# 6     07           190             35             190       190.10
# 7     08           190             35             190       198.10
# 8     09           180             33             180       196.20
# 9     10           190             35             190       193.10
# 10    11           176             34             176       186.24
# 11    12           190             35             190       189.10

# %%
date_year=pd.read_sql("""SELECT 
    strftime('%Y', InvoiceDate) AS year,sum(total) as Total_sales from invoice group by year """,conn) 
date_year
# Out:
#    year  Total_sales
# 0  2009       449.46
# 1  2010       481.45
# 2  2011       469.58
# 3  2012       477.53
# 4  2013       450.58

# %%
time_of_playing=pd.read_sql('''SELECT 
    g.Name AS Genre,
    t.Name AS TrackName,
    t.Milliseconds / 1000.0 AS DurationSeconds,
    RANK() OVER (PARTITION BY g.Name ORDER BY t.Milliseconds DESC) AS RankByLength
FROM Track t
JOIN Genre g ON t.GenreId = g.GenreId
ORDER BY g.Name, RankByLength;''',conn)
time_of_playing
# Out:
#             Genre              TrackName  DurationSeconds  RankByLength
# 0     Alternative             Reach Down          672.773             1
# 1     Alternative      Four Walled World          414.474             2
# 2     Alternative     Say Hello 2 Heaven          384.497             3
# 3     Alternative       Times of Trouble          342.539             4
# 4     Alternative          Call Me a Dog          304.458             5
# ...           ...                    ...              ...           ...
# 3498        World          Choramingando          190.484            24
# 3499        World              No Futuro          182.308            25
# 3500        World              Cafezinho          180.924            26
# 3501        World  Cuando Eu For Pro Ceu          118.804            27
# 3502        World               Demorou!           39.131            28
#
# [3503 rows x 4 columns]

# %%
customers_and_orders=pd.read_sql('''SELECT 
    c.Country,
    c.CustomerId,
    c.FirstName || ' ' || c.LastName AS CustomerName,
    COUNT(i.InvoiceId) AS TotalInvoices,
    ROW_NUMBER() OVER (PARTITION BY c.Country ORDER BY COUNT(i.InvoiceId) DESC) AS RowNum
FROM Customer c
JOIN Invoice i ON c.CustomerId = i.CustomerId
GROUP BY c.Country, c.CustomerId
ORDER BY c.Country, RowNum;'''
,conn)
customers_and_orders
# Out:
#            Country  CustomerId           CustomerName  TotalInvoices  RowNum
# 0        Argentina          56        Diego Gutiérrez              7       1
# 1        Australia          55            Mark Taylor              7       1
# 2          Austria           7          Astrid Gruber              7       1
# 3          Belgium           8           Daan Peeters              7       1
# 4           Brazil           1         Luís Gonçalves              7       1
# 5           Brazil          10        Eduardo Martins              7       2
# 6           Brazil          11        Alexandre Rocha              7       3
# 7           Brazil          12        Roberto Almeida              7       4
# 8           Brazil          13         Fernanda Ramos              7       5
# 9           Canada           3      François Tremblay              7       1
# 10          Canada          14           Mark Philips              7       2
# ...
